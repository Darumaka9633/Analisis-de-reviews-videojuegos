# %% [markdown]
# # Web Scraping de APIs: Metacritic y RAWG
#
# En este proyecto, exploraremos el web scraping de las APIs de Metacritic y RAWG para obtener información de juegos. Aprenderemos cómo realizar solicitudes HTTP, analizar respuestas JSON y extraer datos relevantes de las APIs.
#
# Índice:
#
# 1. Introducción a Metacritic
# 2. Web Scraping de Metacritic
# 3. Introducción a RAWG
# 4. Web Scraping de RAWG
# 5. Comparación de Metascores

# %% [markdown]
# ## 1. Introducción a Metacritic
# Metacritic es un sitio web que recopila reseñas de juegos, películas, música y televisión de múltiples fuentes y les asigna una puntuación agregada. La API de Metacritic nos permite acceder a la información de juegos, incluyendo títulos, géneros, desarrolladores y puntuaciones de críticos y usuarios.

# %% [markdown]
# ## 2. Web Scraping de Metacritic
# En esta sección, aprenderemos cómo realizar web scraping de la API de Metacritic para obtener información de juegos. Veremos cómo realizar solicitudes HTTP, analizar respuestas JSON y extraer datos relevantes.

# %% [markdown]
# ### 2.1 Datos relevantes
# por ejemplo podemos extraer el top de juegos actuales que ya se lanzaron o proximos titulos a lanzarse en este año

# %%
import requests
from json.decoder import JSONDecodeError

url = "https://metacriticapi.p.rapidapi.com/games/top"
headers = {
    "X-RapidAPI-Key": "ca578d1629msh29e6128cab61badp110658jsnefac65d5e1e4",
    "X-RapidAPI-Host": "metacriticapi.p.rapidapi.com"
}

try:
    response = requests.get(url, headers=headers)
    data = response.json()
    print(data)
except JSONDecodeError as e:
    print("Error al decodificar el JSON:", str(e))
# Out:
# [{'platform': None, 'developer': None, 'title': 'The Legend of Zelda: Tears of the Kingdom', 'description': 'An epic adventure across the land and skies of Hyrule awaits in The Legend of Zelda™: Tears of the Kingdom for Nintendo Switch™. The adventure is yours to create in a world fueled by your imagination. In this sequel to The Legend of Zelda: Breath of the Wild, you’ll decide your own path through the sprawling landscapes of Hyrule and the mysterious islands floating in the vast skies above. Can you harness the power of Link’s new abilities to fight back against the malevolent forces that threaten the kingdom?', 'genre': None, 'thumbnailUrl': 'https://static.metacritic.com/images/products/games/0/7529054a2e91ed554500f775fb15370b-98.jpg', 'metaScore': 96, 'userScore': 86, 'releaseDate': '2023-05-12T00:00:00', 'recentReviews': None, 'recentUserReviews': None}, {'platform': None, 'developer': None, 'title': 'Jack Jeanne', 'description': 'The game\'s story centers around protagonist Kisa Tachibana, a girl who had given up on a career in theater, but receives an invitation to attend the Univeil Drama School, an elite drama school for male actors, where students play female roles (referred to as "Jeanne" roles) in addition to male roles ("Jack" roles). However, to maintain her enrollment, she must land a starring role in the school\'s play at the end of the year and also hide that she is a girl.', 'genre': None, 'thumbnailUrl': 'https://static.metacritic.com/images/products/games/9/70b9c9c98b7d3dc2c1e4e64c5c736cf9-98.jpg', 'metaScore': 95, 'userScore': None, 'releaseDate': '2023-05-12T00:00:00', 'recentReviews': None, 'recentUserReviews': None}, {'platform': None, 'developer': None, 'title': 'The Case of the Golden Idol', 'description': 'The Case of the Golden Idol is a wryly amusing detective game set in the 18th century, brought to life with striking hand-drawn artwork. The game tests your ability to piece together clues and reconstruct the events leading up to some mysterious deaths.Investigate a series of mysterious deaths. Explore hand-drawn locations set in the 18th century, where some mysterious deaths have taken place.Reconstruct the events with a unique drag-and-drop mechanic. Gather verbal evidence and visual clues, then apply your deduction skills to figure out what actually happened and how each victim died.Explore a greater mystery that spans centuries. Start revealing a larger overarching story that connects all the individual tales.', 'genre': None, 'thumbnailUrl': 'https://static.metacritic.com/images/products/games/7/9b68ccea0ac9d79dc50fa684f6e2fb89-98.jpg', 'metaScore': 93, 'userScore': None, 'releaseDate': '2023-05-12T00:00:00', 'recentReviews': None, 'recentUserReviews': None}, {'platform': None, 'developer': None, 'title': 'Street Fighter 6', 'description': 'Powered by Capcom’s proprietary RE ENGINE, the Street Fighter 6 experience spans across three distinct game modes featuring World Tour, Fighting Ground and Battle Hub. Diverse Roster of 18 Fighters. Play legendary masters and new fan favorites like Ryu, Chun-Li, Luke, Jamie, Kimberly and more in this latest edition with each character featuring striking new redesigns and exhilarating cinematic specials. Street Fighter 6 offers a highly evolved combat system with three control types - Classic, Modern and Dynamic - allowing you to quickly play to your skill level. The new Real Time Commentary Feature adds all the hype of a competitive match as well as easy-to-understand explanations about your gameplay. The Drive Gauge is a new system to manage your resources. Use it wisely in order to claim victory.', 'genre': None, 'thumbnailUrl': 'https://static.metacritic.com/images/products/games/3/4e47e230267a95fbe60fa9806b628b38-98.jpg', 'metaScore': 92, 'userScore': 50, 'releaseDate': '2023-05-12T00:00:00', 'recentReviews': None, 'recentUserReviews': None}, {'platform': None, 'developer': None, 'title': 'Xenoblade Chronicles 3: Expansion Pass Wave 4 - Future Redeem ...

# %% [markdown]
# Colocamos los datos anteriores en un data frame

# %%
import pandas as pd

data = [
    {
        'platform': None,
        'developer': None,
        'title': 'The Legend of Zelda: Tears of the Kingdom',
        'description': 'An epic adventure across the land and skies of Hyrule awaits...',
        'genre': None,
        'thumbnailUrl': 'https://static.metacritic.com/images/products/games/0/7529054a2e91ed554500f775fb15370b-98.jpg',
        'metaScore': 96,
        'userScore': 86,
        'releaseDate': '2023-05-12T00:00:00',
        'recentReviews': None,
        'recentUserReviews': None
    },
    {
        'platform': None,
        'developer': None,
        'title': 'Jack Jeanne',
        'description': 'The game\'s story centers around protagonist Kisa Tachibana...',
        'genre': None,
        'thumbnailUrl': 'https://static.metacritic.com/images/products/games/9/70b9c9c98b7d3dc2c1e4e64c5c736cf9-98.jpg',
        'metaScore': 95,
        'userScore': None,
        'releaseDate': '2023-05-12T00:00:00',
        'recentReviews': None,
        'recentUserReviews': None
    },
    {
        'platform': None,
        'developer': None,
        'title': 'The Case of the Golden Idol',
        'description': 'The Case of the Golden Idol is a wryly amusing detective game set...',
        'genre': None,
        'thumbnailUrl': 'https://static.metacritic.com/images/products/games/7/9b68ccea0ac9d79dc50fa684f6e2fb89-98.jpg',
        'metaScore': 93,
        'userScore': None,
        'releaseDate': '2023-05-12T00:00:00',
        'recentReviews': None,
        'recentUserReviews': None
    },
    {
        'platform': None,
        'developer': None,
        'title': 'Street Fighter 6',
        'description': 'Powered by Capcom’s proprietary RE ENGINE, the Street Fighter 6...',
        'genre': None,
        'thumbnailUrl': 'https://static.metacritic.com/images/products/games/3/4e47e230267a95fbe60fa9806b628b38-98.jpg',
        'metaScore': 92,
        'userScore': 50,
        'releaseDate': '2023-05-12T00:00:00',
        'recentReviews': None,
        'recentUserReviews': None
    },
    {
        'platform': None,
        'developer': None,
        'title': 'Xenoblade Chronicles 3: Expansion Pass Wave 4 - Future Redeemed',
        'description': 'Set before the events of Xenoblade Chronicles 3, join a cast of new...',
        'genre': None,
        'thumbnailUrl': 'https://static.metacritic.com/images/products/games/1/74f68686e0143e5fe19b2a8b615fb716-98.jpg',
        'metaScore': 92,
        'userScore': 89,
        'releaseDate': '2023-05-12T00:00:00',
        'recentReviews': None,
        'recentUserReviews': None
    }
]

df = pd.DataFrame(data)
df.to_csv('games.csv', index=False)
df
# Out:
#   platform developer                                              title  \
# 0     None      None          The Legend of Zelda: Tears of the Kingdom
# 1     None      None                                        Jack Jeanne
# 2     None      None                        The Case of the Golden Idol
# 3     None      None                                   Street Fighter 6
# 4     None      None  Xenoblade Chronicles 3: Expansion Pass Wave 4 ...
#
#                                          description genre  \
# 0  An epic adventure across the land and skies of...  None
# 1  The game's story centers around protagonist Ki...  None
# 2  The Case of the Golden Idol is a wryly amusing...  None
# 3  Powered by Capcom’s proprietary RE ENGINE, the...  None
# 4  Set before the events of Xenoblade Chronicles ...  None
#
#                                         thumbnailUrl  metaScore  userScore  \
# 0  https://static.metacritic.com/images/products/...         96       86.0
# 1  https://static.metacritic.com/images/products/...         95        NaN
# 2  https://static.metacritic.com/images/products/...         93        NaN
# 3  https://static.metacritic.com/images/products/...         92       50.0
# 4  https://static.metacritic.com/images/products/...         92       89.0
#
#            releaseDate recentReviews recentUserReviews
# 0  2023-05-12T00:00:00          None              None
# 1  2023-05-12T00:00:00          None              None
# 2  2023-05-12T00:00:00          None              None
# 3  2023-05-12T00:00:00          None              None
# 4  2023-05-12T00:00:00          None              None

# %% [markdown]
# ### 2.2  Datos adicionales
# utilizando el ID de un juego específico y muestra la información del juego, como el título, género, desarrollador, metascore y userscore.

# %%
import requests

# Solicitar al usuario que ingrese el ID del juego
game_id = input("Ingresa el ID del juego: ")

# Construir la URL utilizando el ID del juego ingresado
url = f"https://metacriticapi.p.rapidapi.com/games/{game_id}"

headers = {
    "X-RapidAPI-Key": "9cec517409msh53db5f49ceb8bbdp194360jsn39f741c79e7a",
    "X-RapidAPI-Host": "metacriticapi.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

data = response.json()

# Comprobar si se obtuvo una respuesta válida
if response.status_code == 200:
    # Obtener los datos del juego
    game_title = data["title"]
    genre = data["genre"]
    developer = data["developer"]
    meta_score = data["metaScore"]
    user_score = data["userScore"]

    # Imprimir los datos del juego
    print("Title:", game_title)
    print("Genre:", genre)
    print("Developer:", developer)
    print("Meta Score:", meta_score)
    print("User Score:", user_score)
else:
    print("No se pudo obtener la información del juego.")
# Out:
# Ingresa el ID del juego: the-witcher-3-wild-hunt
# Title: The Witcher 3: Wild Hunt          		  PC
# Genre: Action RPG, Role-Playing, Action RPG
# Developer: CD Projekt Red Studio
# Meta Score: 93
# User Score: 91

# %% [markdown]
# ## 3. Introducción a RAWG
#
# RAWG es una base de datos de videojuegos que ofrece información detallada sobre juegos, incluyendo títulos, géneros, plataformas y calificaciones de usuarios. La API de RAWG nos permite acceder a esta información y realizar búsquedas de juegos específicos.

# %% [markdown]
# ## 4. Web Scraping de RAWG
# En esta sección, aprenderemos cómo realizar web scraping de la API de RAWG para obtener información de juegos. Veremos cómo realizar solicitudes HTTP, analizar respuestas JSON y extraer datos relevantes

# %% [markdown]
# ### 4.1 Datos relevantes
# realiza una solicitud a la API de RAWG para obtener las reviews de videojuegos, ordenadas por rating descendente. Luego, muestra la información de cada juego, incluyendo el nombre, rating, plataformas y fecha de lanzamiento pero de solo los primeros 100 juegos como ejemplo

# %%
import requests

# URL de la API de reviews de videojuegos
url = "https://api.rawg.io/api/games"

# Parámetros de la solicitud
params = {
    "key": "6a993b331c264a5995c5b548aa104274",  # se necesita una API key para esta API específica
    "page_size": 100,  # Número de resultados por página
    "ordering": "-rating",  # Ordenar por rating descendente
}

# Realizar la solicitud HTTP a la API
response = requests.get(url, params=params)

# Comprobar el código de respuesta
if response.status_code == 200:
    # Parsear la respuesta JSON
    data = response.json()

    # Extraer las reviews de videojuegos
    results = data["results"]

    # Iterar sobre los resultados y mostrar las reviews
    for result in results:
        name = result["name"]
        rating = result["rating"]
        platforms = result["platforms"]
        released = result["released"]

        print(f"Juego: {name}")
        print(f"Rating: {rating}")
        print(f"Plataformas: {platforms}")
        print(f"Lanzamiento: {released}")
        print("------------------------------------")
else:
    print("Error al realizar la solicitud HTTP:", response.status_code)
# Out:
# Juego: Door Kickers 2: Task Force North
# Rating: 4.83
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2020-11-03', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 55, 'name': 'Classic Macintosh', 'slug': 'macintosh', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 676, 'image_background': 'https://media.rawg.io/media/screenshots/f6b/f6b3338889ec877c9d3d89fc4f665152.jpg'}, 'released_at': '2020-11-03', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2020-11-03
# ------------------------------------
# Juego: Volfied (1989)
# Rating: 4.83
# Plataformas: [{'platform': {'id': 11, 'name': 'Wii', 'slug': 'wii', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 2251, 'image_background': 'https://media.rawg.io/media/screenshots/4f2/4f2246a85225b7a91d63990fe540b7c4.jpg'}, 'released_at': '1989-01-01', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 166, 'name': 'Commodore / Amiga', 'slug': 'commodore-amiga', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 2076, 'image_background': 'https://media.rawg.io/media/games/cfd/cfdfaaddca4f351b27f965a2f97af0f4.jpg'}, 'released_at': '1989-01-01', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 34, 'name': 'Atari ST', 'slug': 'atari-st', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 835, 'image_background': 'https://media.rawg.io/media/games/32d/32d851318b042aba3df62e52d868d599.jpg'}, 'released_at': '1989-01-01', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '1989-01-01', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 167, 'name': 'Genesis', 'slug': 'genesis', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 828, 'image_background': 'https://media.rawg.io/media/games/637/637d7dc2f44d0f6ddd3ee2c0b1366962.jpg'}, 'released_at': '1989-01-01', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 1989-01-01
# ------------------------------------
# Juego: The Witcher 3: Wild Hunt – Blood and Wine
# Rating: 4.8
# Plataformas: [{'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 6655, 'image_background': 'https://media.rawg.io/media/games/9fa/9fa63622543e5d4f6d99aa9d73b043de.jpg'}, 'released_at': '2016-05-30', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2016-05-30', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 5525, 'image_background': 'https://media.rawg.io/media/games/fc1/fc1307a2774506b5bd65d7e8424664a7.jpg'}, 'released_at': '2016-05-30', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2016-05-30
# ------------------------------------
# Juego: The Witcher 3: Game of the Year
# Rating: 4.79
# Plataformas: [{'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 5525, 'image_background': 'https://media.rawg.io/media/games/fc1/fc1307a2774506b5bd65d7e8424664a7.jpg'}, 'released_at': '2016-08-30', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2016-08-30', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 7, 'name': 'Nintendo Switch', 'slug': 'nintendo-switch', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 5264, 'image_background': 'https://media.rawg.io/media/games/c6b/c6bfece1daf8d06bc0a60632ac78e5bf.jpg'}, 'released_at': '2016-08-30', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 6655, 'image_background': 'https://media.rawg.io/media/games/9fa/9fa63622543e5d4f6d99aa9d73b043de.jpg'}, 'released_at': '2016-08-30', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 187, 'name': 'PlayStation 5', 'slug': 'playstation5', 'image': None, 'year_end': None, 'year_start': 2020, 'games_count': 893, 'image_background': 'https://media.rawg.io/media/games/5ec/5ecac5cb026ec26a56efcc546364e348.jpg'}, 'released_at': '2016-08-30', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2016-08-30
# ------------------------------------
# Juego: Persona 5 Royal
# Rating: 4.76
# Plataformas: [{'platform': {'id': 186, 'name': 'Xbox Series S/X', 'slug': 'xbox-series-x', 'image': None, 'year_end': None, 'year_start': 2020, 'games_count': 773, 'image_background': 'https://media.rawg.io/media/games/957/957154d665ae676b00c0859551c733b1.jpg'}, 'released_at': '2020-03-31', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2020-03-31', 'requirements_en': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li>Requires a 64-bit processor and operating system<br></li><li><strong>OS:</strong> Windows 10<br></li><li><strong>Processor:</strong> Intel Core i7-4790, 3.4 GHz | AMD Ryzen 5 1500X, 3.5 GHz<br></li><li><strong>Memory:</strong> 8 GB RAM<br></li><li><strong>Graphics:</strong> Nvidia GeForce GTX 650 Ti, 2 GB | AMD Radeon R7 360, 2 GB<br></li><li><strong>DirectX:</strong> Version 11<br></li><li><strong>Storage:</strong> 41 GB available space<br></li><li><strong>Additional Notes:</strong> Low 720p @ 60 FPS. Requires a CPU which supports the AVX and SSE4.2 instruction set.</li></ul>', 'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li>Requires a 64-bit processor and operating system<br></li><li><strong>OS:</strong> Windows 10<br></li><li><strong>Processor:</strong> Intel Core i7-4790, 3.4 GHz | AMD Ryzen 5 1500X 3.5 Ghz<br></li><li><strong>Memory:</strong> 8 GB RAM<br></li><li><strong>Graphics:</strong> Nvidia GeForce GTX 760, 2 GB | AMD Radeon HD 7870, 2 GB<br></li><li><strong>DirectX:</strong> Version 11<br></li><li><strong>Storage:</strong> 41 GB available space<br></li><li><strong>Additional Notes:</strong> High 1080p @ 60 FPS</li></ul>'}, 'requirements_ru': None}, {'platform': {'id': 187, 'name': 'PlayStation 5', 'slug': 'playstation5', 'image': None, 'year_end': None, 'year_start': 2020, 'games_count': 893, 'image_background': 'https://media.rawg.io/media/games/5ec/5ecac5cb026ec26a56efcc546364e348.jpg'}, 'released_at': '2020-03-31', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 7, 'name': 'Nintendo Switch', 'slug': 'nintendo-switch', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 5264, 'image_background': 'https://media.rawg.io/media/games/c6b/c6bfece1daf8d06bc0a60632ac78e5bf.jpg'}, 'released_at': '2020-03-31', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 5525, 'image_background': 'https://media.rawg.io/media/games/fc1/fc1307a2774506b5bd65d7e8424664a7.jpg'}, 'released_at': '2020-03-31', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 6655, 'image_background': 'https://media.rawg.io/media/games/9fa/9fa63622543e5d4f6d99aa9d73b043de.jpg'}, 'released_at': '2020-03-31', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2020-03-31
# ------------------------------------
# Juego: Lovely Moment with a Married Woman
# Rating: 4.75
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2021-03-31', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2021-03-31
# ------------------------------------
# Juego: Echidna Wars DX
# Rating: 4.75
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2016-12-31', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2016-12-31
# ------------------------------------
# Juego: The Witcher 3: Wild Hunt – Hearts of Stone
# Rating: 4.75
# Plataformas: [{'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 6655, 'image_background': 'https://media.rawg.io/media/games/9fa/9fa63622543e5d4f6d99aa9d73b043de.jpg'}, 'released_at': '2015-10-13', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 5525, 'image_background': 'https://media.rawg.io/media/games/fc1/fc1307a2774506b5bd65d7e8424664a7.jpg'}, 'released_at': '2015-10-13', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2015-10-13', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2015-10-13
# ------------------------------------
# Juego: Mass Effect Trilogy
# Rating: 4.75
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2012-11-06', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 16, 'name': 'PlayStation 3', 'slug': 'playstation3', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 3180, 'image_background': 'https://media.rawg.io/media/games/4e6/4e6e8e7f50c237d76f38f3c885dae3d2.jpg'}, 'released_at': '2012-11-06', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2012-11-06
# ------------------------------------
# Juego: Guilty Parade
# Rating: 4.71
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': None, 'requirements_en': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows XP/7/8/8.1/10<br></li><li><strong>Processor:</strong> 1.2 GHz<br></li><li><strong>Memory:</strong> 1 GB RAM<br></li><li><strong>Storage:</strong> 500 MB available space</li></ul>'}, 'requirements_ru': None}, {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 101641, 'image_background': 'https://media.rawg.io/media/games/ee3/ee3e10193aafc3230ba1cae426967d10.jpg'}, 'released_at': None, 'requirements_en': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> OS X 10.6+<br></li><li><strong>Processor:</strong> 1.2 GHz<br></li><li><strong>Memory:</strong> 1 GB RAM<br></li><li><strong>Storage:</strong> 500 MB available space</li></ul>'}, 'requirements_ru': None}, {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 75233, 'image_background': 'https://media.rawg.io/media/games/16b/16b1b7b36e2042d1128d5a3e852b3b2f.jpg'}, 'released_at': None, 'requirements_en': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Linux x86/x86_64<br></li><li><strong>Processor:</strong> 1.2 GHz<br></li><li><strong>Memory:</strong> 1 GB RAM<br></li><li><strong>Storage:</strong> 500 MB available space</li></ul>'}, 'requirements_ru': None}]
# Lanzamiento: None
# ------------------------------------
# Juego: Star Channel 34
# Rating: 4.71
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2019-05-13', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 101641, 'image_background': 'https://media.rawg.io/media/games/ee3/ee3e10193aafc3230ba1cae426967d10.jpg'}, 'released_at': '2019-05-13', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 75233, 'image_background': 'https://media.rawg.io/media/games/16b/16b1b7b36e2042d1128d5a3e852b3b2f.jpg'}, 'released_at': '2019-05-13', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 21, 'name': 'Android', 'slug': 'android', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 52230, 'image_background': 'https://media.rawg.io/media/games/283/283e7e600366b0da7021883d27159b27.jpg'}, 'released_at': '2019-05-13', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2019-05-13
# ------------------------------------
# Juego: Victoria 2: Heart of Darkness
# Rating: 4.71
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2013-04-16', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2013-04-16
# ------------------------------------
# Juego: Starlancer
# Rating: 4.71
# Plataformas: [{'platform': {'id': 106, 'name': 'Dreamcast', 'slug': 'dreamcast', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 357, 'image_background': 'https://media.rawg.io/media/screenshots/6e4/6e45a8e19beb5d510813f10f8af4eedc.jpg'}, 'released_at': '2000-03-31', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2000-03-31', 'requirements_en': None, 'requirements_ru': {'minimum': 'Pentium 200, 32 Мб, Direct3D 6', 'recommended': 'Pentium II 450, 64 Мб, Direct3D 6'}}]
# Lanzamiento: 2000-03-31
# ------------------------------------
# Juego: Majesty: The Northern Expansion
# Rating: 4.71
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2001-03-01', 'requirements_en': None, 'requirements_ru': {'minimum': 'Pentium 166, 32 Мб', 'recommended': 'Pentium II 266, 64 Мб'}}]
# Lanzamiento: 2001-03-01
# ------------------------------------
# Juego: The Last Of Us Remastered
# Rating: 4.69
# Plataformas: [{'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 6655, 'image_background': 'https://media.rawg.io/media/games/9fa/9fa63622543e5d4f6d99aa9d73b043de.jpg'}, 'released_at': '2014-07-29', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2014-07-29
# ------------------------------------
# Juego: Hollow Knight: Silksong
# Rating: 4.68
# Plataformas: [{'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 75233, 'image_background': 'https://media.rawg.io/media/games/16b/16b1b7b36e2042d1128d5a3e852b3b2f.jpg'}, 'released_at': None, 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': None, 'requirements_en': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows 7<br></li><li><strong>Processor:</strong> Intel Core 2 Duo E5200<br></li><li><strong>Memory:</strong> 4 GB RAM<br></li><li><strong>Graphics:</strong> GeForce 9800GTX+ (1GB)<br></li><li><strong>DirectX:</strong> Version 10<br></li><li><strong>Storage:</strong> 9 GB available space<br></li><li><strong>Additional Notes:</strong> 1080p, 16:9 recommended</li></ul>', 'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows 10<br></li><li><strong>Processor:</strong> Intel Core i5<br></li><li><strong>Memory:</strong> 8 GB RAM<br></li><li><strong>Graphics:</strong> GeForce GTX 560+<br></li><li><strong>DirectX:</strong> Version 10<br></li><li><strong>Storage:</strong> 9 GB available space<br></li><li><strong>Additional Notes:</strong> 1080p, 16:9 recommended</li></ul>'}, 'requirements_ru': None}, {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 101641, 'image_background': 'https://media.rawg.io/media/games/ee3/ee3e10193aafc3230ba1cae426967d10.jpg'}, 'released_at': None, 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 7, 'name': 'Nintendo Switch', 'slug': 'nintendo-switch', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 5264, 'image_background': 'https://media.rawg.io/media/games/c6b/c6bfece1daf8d06bc0a60632ac78e5bf.jpg'}, 'released_at': None, 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2023-12-31
# ------------------------------------
# Juego: FNAF SANDBOX
# Rating: 4.67
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2022-04-02', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2022-04-02
# ------------------------------------
# Juego: The Legend of Heroes: Trails from Zero
# Rating: 4.67
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2022-09-27', 'requirements_en': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li>Requires a 64-bit processor and operating system<br></li><li><strong>OS:</strong> Windows 8.1<br></li><li><strong>Processor:</strong> Intel Core i3<br></li><li><strong>Memory:</strong> 4 GB RAM<br></li><li><strong>Graphics:</strong> AMD Radeon HD 6570<br></li><li><strong>DirectX:</strong> Version 11<br></li><li><strong>Storage:</strong> 4 GB available space</li></ul>', 'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li>Requires a 64-bit processor and operating system<br></li><li><strong>OS:</strong> Windows 10/11<br></li><li><strong>Processor:</strong> Intel Core i5 (4-core 3.30Ghz)<br></li><li><strong>Memory:</strong> 8 GB RAM<br></li><li><strong>Graphics:</strong> AMD Radeon R7 200 Series<br></li><li><strong>DirectX:</strong> Version 11<br></li><li><strong>Storage:</strong> 4 GB available space</li></ul>'}, 'requirements_ru': None}, {'platform': {'id': 7, 'name': 'Nintendo Switch', 'slug': 'nintendo-switch', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 5262, 'image_background': 'https://media.rawg.io/media/games/942/9424d6bb763dc38d9378b488603c87fa.jpg'}, 'released_at': '2022-09-27', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 6655, 'image_background': 'https://media.rawg.io/media/games/9fa/9fa63622543e5d4f6d99aa9d73b043de.jpg'}, 'released_at': '2022-09-27', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2022-09-27
# ------------------------------------
# Juego: Walkabout Mini Golf VR
# Rating: 4.67
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2021-07-15', 'requirements_en': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows 10<br></li><li><strong>Processor:</strong> Intel Core i5-4590/AMD FX 8350 equivalent or better<br></li><li><strong>Memory:</strong> 4 GB RAM<br></li><li><strong>Graphics:</strong> NVIDIA GeForce GTX 970, AMD Radeon R9 290 equivalent or better.<br></li><li><strong>Storage:</strong> 2 GB available space</li></ul>'}, 'requirements_ru': None}]
# Lanzamiento: 2021-07-15
# ------------------------------------
# Juego: Disco Elysium: Final Cut
# Rating: 4.67
# Plataformas: [{'platform': {'id': 187, 'name': 'PlayStation 5', 'slug': 'playstation5', 'image': None, 'year_end': None, 'year_start': 2020, 'games_count': 893, 'image_background': 'https://media.rawg.io/media/games/5ec/5ecac5cb026ec26a56efcc546364e348.jpg'}, 'released_at': '2021-03-30', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 186, 'name': 'Xbox Series S/X', 'slug': 'xbox-series-x', 'image': None, 'year_end': None, 'year_start': 2020, 'games_count': 773, 'image_background': 'https://media.rawg.io/media/games/957/957154d665ae676b00c0859551c733b1.jpg'}, 'released_at': '2021-03-30', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 6655, 'image_background': 'https://media.rawg.io/media/games/9fa/9fa63622543e5d4f6d99aa9d73b043de.jpg'}, 'released_at': '2021-03-30', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 101641, 'image_background': 'https://media.rawg.io/media/games/ee3/ee3e10193aafc3230ba1cae426967d10.jpg'}, 'released_at': '2021-03-30', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2021-03-30', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 3, 'name': 'iOS', 'slug': 'ios', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 76902, 'image_background': 'https://media.rawg.io/media/games/35b/35b47c4d85cd6e08f3e2ca43ea5ce7bb.jpg'}, 'released_at': '2021-03-30', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 7, 'name': 'Nintendo Switch', 'slug': 'nintendo-switch', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 5262, 'image_background': 'https://media.rawg.io/media/games/942/9424d6bb763dc38d9378b488603c87fa.jpg'}, 'released_at': '2021-03-30', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 5525, 'image_background': 'https://media.rawg.io/media/games/fc1/fc1307a2774506b5bd65d7e8424664a7.jpg'}, 'released_at': '2021-03-30', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2021-03-30
# ------------------------------------
# Juego: Grown-Up Titans ( Teen Titans)
# Rating: 4.67
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2021-01-08', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2021-01-08
# ------------------------------------
# Juego: Adventure Island IV
# Rating: 4.67
# Plataformas: [{'platform': {'id': 49, 'name': 'NES', 'slug': 'nes', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 976, 'image_background': 'https://media.rawg.io/media/games/73e/73e2509fef0e46cdbea86e5e8f8822ca.jpg'}, 'released_at': '1994-06-24', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 1994-06-24
# ------------------------------------
# Juego: FNaF: Running in the 80's - FNaF Fan-Game
# Rating: 4.67
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2020-08-13', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2020-08-13
# ------------------------------------
# Juego: siren head simulator (mr bonnie)
# Rating: 4.67
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2020-07-06', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 75233, 'image_background': 'https://media.rawg.io/media/games/16b/16b1b7b36e2042d1128d5a3e852b3b2f.jpg'}, 'released_at': '2020-07-06', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2020-07-06
# ------------------------------------
# Juego: Knightly Passions [0.1a version] (Adult Game) 18+
# Rating: 4.67
# Plataformas: [{'platform': {'id': 21, 'name': 'Android', 'slug': 'android', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 52230, 'image_background': 'https://media.rawg.io/media/games/283/283e7e600366b0da7021883d27159b27.jpg'}, 'released_at': '2020-04-20', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 75233, 'image_background': 'https://media.rawg.io/media/games/16b/16b1b7b36e2042d1128d5a3e852b3b2f.jpg'}, 'released_at': '2020-04-20', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 101641, 'image_background': 'https://media.rawg.io/media/games/ee3/ee3e10193aafc3230ba1cae426967d10.jpg'}, 'released_at': '2020-04-20', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2020-04-20', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2020-04-20
# ------------------------------------
# Juego: Nekketsu Kakutou Densetsu
# Rating: 4.67
# Plataformas: [{'platform': {'id': 49, 'name': 'NES', 'slug': 'nes', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 976, 'image_background': 'https://media.rawg.io/media/games/73e/73e2509fef0e46cdbea86e5e8f8822ca.jpg'}, 'released_at': '1992-12-23', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 1992-12-23
# ------------------------------------
# Juego: Kerbal Space Program 2
# Rating: 4.67
# Plataformas: [{'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 6655, 'image_background': 'https://media.rawg.io/media/games/9fa/9fa63622543e5d4f6d99aa9d73b043de.jpg'}, 'released_at': '2023-02-23', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 5525, 'image_background': 'https://media.rawg.io/media/games/fc1/fc1307a2774506b5bd65d7e8424664a7.jpg'}, 'released_at': '2023-02-23', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2023-02-23', 'requirements_en': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> System Requirements Coming Soon</li></ul>', 'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> System Requirements Coming Soon</li></ul>'}, 'requirements_ru': None}]
# Lanzamiento: 2023-02-23
# ------------------------------------
# Juego: Project Gotham Racing 2
# Rating: 4.67
# Plataformas: [{'platform': {'id': 80, 'name': 'Xbox', 'slug': 'xbox-old', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 722, 'image_background': 'https://media.rawg.io/media/games/e60/e601c02ec49ef4f1d5ef147994b3935f.jpg'}, 'released_at': '2003-11-17', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2003-11-17
# ------------------------------------
# Juego: Shining Force III
# Rating: 4.67
# Plataformas: [{'platform': {'id': 107, 'name': 'SEGA Saturn', 'slug': 'sega-saturn', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 348, 'image_background': 'https://media.rawg.io/media/games/18f/18f130a198e4c6f1970ad1f36dda7d1f.jpg'}, 'released_at': '1997-12-11', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 1997-12-11
# ------------------------------------
# Juego: Godzilla Save the Earth
# Rating: 4.67
# Plataformas: [{'platform': {'id': 15, 'name': 'PlayStation 2', 'slug': 'playstation2', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 1977, 'image_background': 'https://media.rawg.io/media/games/233/233cdc08cce0228f6f35222eca3bff92.jpg'}, 'released_at': '2004-11-02', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 80, 'name': 'Xbox', 'slug': 'xbox-old', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 722, 'image_background': 'https://media.rawg.io/media/games/e60/e601c02ec49ef4f1d5ef147994b3935f.jpg'}, 'released_at': '2004-11-02', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2004-11-02
# ------------------------------------
# Juego: Valkyrie Profile 2: Silmeria
# Rating: 4.67
# Plataformas: [{'platform': {'id': 15, 'name': 'PlayStation 2', 'slug': 'playstation2', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 1977, 'image_background': 'https://media.rawg.io/media/games/233/233cdc08cce0228f6f35222eca3bff92.jpg'}, 'released_at': None, 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2006-09-26
# ------------------------------------
# Juego: Modern Strike Online: PRO FPS!
# Rating: 4.67
# Plataformas: [{'platform': {'id': 21, 'name': 'Android', 'slug': 'android', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 52230, 'image_background': 'https://media.rawg.io/media/games/283/283e7e600366b0da7021883d27159b27.jpg'}, 'released_at': None, 'requirements_en': {'minimum': '4.1 and up'}, 'requirements_ru': None}]
# Lanzamiento: None
# ------------------------------------
# Juego: House Designer: Fix & Flip
# Rating: 4.67
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '2023-02-21', 'requirements_en': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Win 10<br></li><li><strong>Processor:</strong> Intel core 2 duo 2.4GHz<br></li><li><strong>Memory:</strong> 2 GB RAM<br></li><li><strong>Graphics:</strong> Video Card with Shader model 3.0<br></li><li><strong>DirectX:</strong> Version 10<br></li><li><strong>Storage:</strong> 1 GB available space<br></li><li><strong>Sound Card:</strong> any</li></ul>', 'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Win 10<br></li><li><strong>Processor:</strong> Intel core i3 or similar<br></li><li><strong>Memory:</strong> 2 GB RAM<br></li><li><strong>Graphics:</strong> Nvidia GeForce 1050 or similar from AMD<br></li><li><strong>DirectX:</strong> Version 11<br></li><li><strong>Storage:</strong> 1 GB available space<br></li><li><strong>Sound Card:</strong> any</li></ul>'}, 'requirements_ru': None}, {'platform': {'id': 3, 'name': 'iOS', 'slug': 'ios', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 76902, 'image_background': 'https://media.rawg.io/media/games/35b/35b47c4d85cd6e08f3e2ca43ea5ce7bb.jpg'}, 'released_at': '2018-08-17', 'requirements_en': {'minimum': 'iPad 2 Wifi, iPad 2 3G, iPhone 4S, iPad Third Gen, iPad Third Gen 4G, iPhone 5, iPod Touch Fifth Gen, iPad Fourth Gen, iPad Fourth Gen 4G, iPad Mini, iPad Mini 4G, iPhone 5c, iPhone 5s, iPad Air, iPad Air Cellular, iPad Mini Retina, iPad Mini Retina Cellular, iPhone 6, iPhone 6 Plus, iPad Air 2, iPad Air 2 Cellular, iPad Mini 3, iPad Mini 3 Cellular, iPod Touch Sixth Gen, iPhone 6s, iPhone 6s Plus, iPad Mini 4, iPad Mini 4 Cellular, iPad Pro, iPad Pro Cellular, iPad Pro 9.7, iPad Pro 9.7 Cellular, iPhone SE, iPhone 7, iPhone 7 Plus, iPad 6 1 1, iPad 6 1 2, iPad 7 1, iPad 7 2, iPad 7 3, iPad 7 4, iPhone 8, iPhone 8 Plus, iPhone X, iPad 7 5, iPad 7 6, iPhone X S, iPhone X S Max, iPhone X R, iPad 8 1 2, iPad 8 3 4, iPad 8 5 6, iPad 8 7 8, iPad Mini 5, iPad Mini 5 Cellular, iPad Air 3, iPad Air 3 Cellular, iPod Touch Seventh Gen'}, 'requirements_ru': None}, {'platform': {'id': 21, 'name': 'Android', 'slug': 'android', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 52230, 'image_background': 'https://media.rawg.io/media/games/283/283e7e600366b0da7021883d27159b27.jpg'}, 'released_at': None, 'requirements_en': {'minimum': '4.1 and up'}, 'requirements_ru': None}]
# Lanzamiento: 2018-08-17
# ------------------------------------
# Juego: Red Ball 4 (Ad Supported)
# Rating: 4.67
# Plataformas: [{'platform': {'id': 3, 'name': 'iOS', 'slug': 'ios', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 76902, 'image_background': 'https://media.rawg.io/media/games/35b/35b47c4d85cd6e08f3e2ca43ea5ce7bb.jpg'}, 'released_at': '2016-04-09', 'requirements_en': {'minimum': 'iPad 2 Wifi, iPad 2 3G, iPhone 4S, iPad Third Gen, iPad Third Gen 4G, iPhone 5, iPod Touch Fifth Gen, iPad Fourth Gen, iPad Fourth Gen 4G, iPad Mini, iPad Mini 4G, iPhone 5c, iPhone 5s, iPad Air, iPad Air Cellular, iPad Mini Retina, iPad Mini Retina Cellular, iPhone 6, iPhone 6 Plus, iPad Air 2, iPad Air 2 Cellular, iPad Mini 3, iPad Mini 3 Cellular, iPod Touch Sixth Gen, iPhone 6s, iPhone 6s Plus, iPad Mini 4, iPad Mini 4 Cellular, iPad Pro, iPad Pro Cellular, iPad Pro 9.7, iPad Pro 9.7 Cellular, iPhone SE, iPhone 7, iPhone 7 Plus, iPad 6 1 1, iPad 6 1 2, iPad 7 1, iPad 7 2, iPad 7 3, iPad 7 4, iPhone 8, iPhone 8 Plus, iPhone X, iPad 7 5, iPad 7 6, iPhone X S, iPhone X S Max, iPhone X R, iPad 8 1 2, iPad 8 3 4, iPad 8 5 6, iPad 8 7 8, iPad Mini 5, iPad Mini 5 Cellular, iPad Air 3, iPad Air 3 Cellular, iPod Touch Seventh Gen'}, 'requirements_ru': None}]
# Lanzamiento: 2016-04-09
# ------------------------------------
# Juego: Jump Ultimate Stars
# Rating: 4.67
# Plataformas: [{'platform': {'id': 9, 'name': 'Nintendo DS', 'slug': 'nintendo-ds', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 2476, 'image_background': 'https://media.rawg.io/media/games/852/8522935d8ab27b610a254b52de0da212.jpg'}, 'released_at': '2006-11-23', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2006-11-23
# ------------------------------------
# Juego: Dai Gyakuten Saiban 2: Naruhodō Ryūnosuke no Kakugo (Ace Attorney)
# Rating: 4.67
# Plataformas: [{'platform': {'id': 3, 'name': 'iOS', 'slug': 'ios', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 76902, 'image_background': 'https://media.rawg.io/media/games/35b/35b47c4d85cd6e08f3e2ca43ea5ce7bb.jpg'}, 'released_at': None, 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 21, 'name': 'Android', 'slug': 'android', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 52230, 'image_background': 'https://media.rawg.io/media/games/283/283e7e600366b0da7021883d27159b27.jpg'}, 'released_at': None, 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 8, 'name': 'Nintendo 3DS', 'slug': 'nintendo-3ds', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 1704, 'image_background': 'https://media.rawg.io/media/screenshots/b83/b8382775bded4811c7492cc5d850683a.jpg'}, 'released_at': None, 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 2017-01-01
# ------------------------------------
# Juego: Warsong
# Rating: 4.67
# Plataformas: [{'platform': {'id': 11, 'name': 'Wii', 'slug': 'wii', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 2251, 'image_background': 'https://media.rawg.io/media/screenshots/4f2/4f2246a85225b7a91d63990fe540b7c4.jpg'}, 'released_at': '1991-04-26', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '1991-04-26', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 167, 'name': 'Genesis', 'slug': 'genesis', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 828, 'image_background': 'https://media.rawg.io/media/games/637/637d7dc2f44d0f6ddd3ee2c0b1366962.jpg'}, 'released_at': '1991-04-26', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 1991-04-26
# ------------------------------------
# Juego: Virtua Racing
# Rating: 4.67
# Plataformas: [{'platform': {'id': 117, 'name': 'SEGA 32X', 'slug': 'sega-32x', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 46, 'image_background': 'https://media.rawg.io/media/screenshots/d9f/d9f308b5d824ae8f047edc0a998a587b.jpg'}, 'released_at': '1992-08-01', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 167, 'name': 'Genesis', 'slug': 'genesis', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 828, 'image_background': 'https://media.rawg.io/media/games/637/637d7dc2f44d0f6ddd3ee2c0b1366962.jpg'}, 'released_at': '1992-08-01', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 107, 'name': 'SEGA Saturn', 'slug': 'sega-saturn', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 348, 'image_background': 'https://media.rawg.io/media/games/18f/18f130a198e4c6f1970ad1f36dda7d1f.jpg'}, 'released_at': '1992-08-01', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 7, 'name': 'Nintendo Switch', 'slug': 'nintendo-switch', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 5264, 'image_background': 'https://media.rawg.io/media/games/c6b/c6bfece1daf8d06bc0a60632ac78e5bf.jpg'}, 'released_at': '1992-08-01', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 1992-08-01
# ------------------------------------
# Juego: Turrican
# Rating: 4.67
# Plataformas: [{'platform': {'id': 166, 'name': 'Commodore / Amiga', 'slug': 'commodore-amiga', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 2076, 'image_background': 'https://media.rawg.io/media/games/cfd/cfdfaaddca4f351b27f965a2f97af0f4.jpg'}, 'released_at': '1990-01-01', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 26, 'name': 'Game Boy', 'slug': 'game-boy', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 607, 'image_background': 'https://media.rawg.io/media/games/e9a/e9a782a3f40f0e53ab64c7018251053e.jpg'}, 'released_at': '1990-01-01', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 4, 'name': 'PC', 'slug': 'pc', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 513840, 'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'}, 'released_at': '1990-01-01', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 34, 'name': 'Atari ST', 'slug': 'atari-st', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 835, 'image_background': 'https://media.rawg.io/media/games/32d/32d851318b042aba3df62e52d868d599.jpg'}, 'released_at': '1990-01-01', 'requirements_en': None, 'requirements_ru': None}, {'platform': {'id': 167, 'name': 'Genesis', 'slug': 'genesis', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 828, 'image_background': 'https://media.rawg.io/media/games/637/637d7dc2f44d0f6ddd3ee2c0b1366962.jpg'}, 'released_at': '1990-01-01', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 1990-01-01
# ------------------------------------
# Juego: Rockin' Kats
# Rating: 4.67
# Plataformas: [{'platform': {'id': 49, 'name': 'NES', 'slug': 'nes', 'image': None, 'year_end': None, 'year_start': None, 'games_count': 976, 'image_background': 'https://media.rawg.io/media/games/73e/73e2509fef0e46cdbea86e5e8f8822ca.jpg'}, 'released_at': '1991-04-05', 'requirements_en': None, 'requirements_ru': None}]
# Lanzamiento: 1991-04-05
# ------------------------------------

# %% [markdown]
# Luego le permitimos al  usuario ingresar el nombre de un juego y obtiene información sobre ese juego desde la API de Rawg.io, incluyendo el rating, las plataformas disponibles, la fecha de lanzamiento y, si está disponible, una descripción del juego.

# %%
import requests

# URL base de la API de Rawg.io
base_url = "https://api.rawg.io/api"

# Obtener el nombre del juego del usuario
game_name = input("Ingresa el nombre del juego: ")

# Endpoint para buscar juegos
search_endpoint = "/games"

# Parámetros de la solicitud
params = {
    "key": "6a993b331c264a5995c5b548aa104274",  # Reemplaza con tu propia clave de API
    "search": game_name,  # Nombre del juego a buscar
    "page_size": 1  # Obtener solo un juego
}

# Realizar la solicitud HTTP a la API
response = requests.get(base_url + search_endpoint, params=params)

# Comprobar el código de respuesta
if response.status_code == 200:
    # Parsear la respuesta JSON
    data = response.json()

    # Comprobar si se encontraron juegos
    if data["count"] > 0:
        # Obtener el primer juego de los resultados
        game = data["results"][0]

        # Mostrar la información del juego
        print("Información del juego:")
        print("Nombre: ", game["name"])
        print("Rating: ", game["rating"])
        print("Plataformas: ", ", ".join([platform["platform"]["name"] for platform in game["platforms"]]))
        print("Lanzamiento: ", game["released"])
        
        if "description" in game:
            print("Descripción: ", game["description"])
        else:
            print("No hay descripción disponible.")
    else:
        print("No se encontraron juegos con ese nombre.")
else:
    print("Error al realizar la solicitud HTTP:", response.status_code)
# Out:
# Ingresa el nombre del juego: grand theft auto v
# Información del juego:
# Nombre:  Grand Theft Auto V
# Rating:  4.47
# Plataformas:  PC, PlayStation 5, Xbox One, PlayStation 4, Xbox Series S/X, Xbox 360, PlayStation 3
# Lanzamiento:  2013-09-17
# No hay descripción disponible.

# %% [markdown]
# ### 4.2 Comentario de la api rawg
#
# Realizamos una solicitud a la API de RAWG para obtener información sobre todos los juegos disponibles. Luego, itera sobre cada juego y muestra su nombre y el "rate" correspondiente al rating más alto ya sea:
#
# exceptional
# recommended
# meh
# skip
#
# esos adjetivos son utilizados para calificar todos los juegos

# %%
import requests

def extract_all_game_rates():
    # URL de la API de RAWG para obtener los juegos
    url = "https://api.rawg.io/api/games"

    # Parámetros de la solicitud
    params = {
        "key": "6a993b331c264a5995c5b548aa104274",  #  se necesita una API key para esta API específica
        "page_size": 100,  # Número de juegos por página
    }

    # Realizar la solicitud HTTP a la API para obtener los juegos
    response = requests.get(url, params=params)

    # Comprobar el código de respuesta
    if response.status_code == 200:
        # Obtener la información de los juegos en formato JSON
        game_data = response.json()

        # Verificar si se encontraron juegos
        if game_data["count"] > 0:
            # Iterar sobre los juegos y mostrar sus rates
            print("Rates de todos los juegos:")
            for game in game_data["results"]:
                game_name = game["name"]
                game_rating = game["rating_top"]
                game_rates = game["ratings"]

                # Buscar el rate correspondiente al rating_top
                rate = ""
                for game_rate in game_rates:
                    if game_rate["id"] == game_rating:
                        rate = game_rate["title"]
                        break

                print(f"Juego: {game_name} | Rate: {rate}")
        else:
            print("No se encontraron juegos.")
    else:
        print("Error al obtener los juegos:", response.status_code)

# Ejemplo de uso: Extraer el rate de todos los juegos
extract_all_game_rates()
# Out:
# Rates de todos los juegos:
# Juego: Grand Theft Auto V | Rate: exceptional
# Juego: The Witcher 3: Wild Hunt | Rate: exceptional
# Juego: Portal 2 | Rate: exceptional
# Juego: Tomb Raider (2013) | Rate: recommended
# Juego: Counter-Strike: Global Offensive | Rate: recommended
# Juego: Portal | Rate: exceptional
# Juego: Left 4 Dead 2 | Rate: recommended
# Juego: The Elder Scrolls V: Skyrim | Rate: exceptional
# Juego: BioShock Infinite | Rate: exceptional
# Juego: Red Dead Redemption 2 | Rate: exceptional
# Juego: Life is Strange | Rate: exceptional
# Juego: Borderlands 2 | Rate: recommended
# Juego: Half-Life 2 | Rate: exceptional
# Juego: BioShock | Rate: exceptional
# Juego: Limbo | Rate: recommended
# Juego: God of War (2018) | Rate: exceptional
# Juego: Destiny 2 | Rate: recommended
# Juego: Fallout 4 | Rate: recommended
# Juego: DOOM (2016) | Rate: exceptional
# Juego: Team Fortress 2 | Rate: recommended
# Juego: PAYDAY 2 | Rate: recommended
# Juego: Horizon Zero Dawn | Rate: exceptional
# Juego: Grand Theft Auto IV | Rate: recommended
# Juego: Rocket League | Rate: recommended
# Juego: Cyberpunk 2077 | Rate: exceptional
# Juego: Terraria | Rate: recommended
# Juego: Dota 2 | Rate: meh
# Juego: Warframe | Rate: recommended
# Juego: Metro 2033 | Rate: recommended
# Juego: Metal Gear Solid V: The Phantom Pain | Rate: exceptional
# Juego: Rise of the Tomb Raider | Rate: recommended
# Juego: Batman: Arkham Knight | Rate: recommended
# Juego: The Walking Dead: Season 1 | Rate: exceptional
# Juego: The Witcher 2: Assassins of Kings Enhanced Edition | Rate: recommended
# Juego: Half-Life 2: Lost Coast | Rate: recommended
# Juego: Grand Theft Auto: San Andreas | Rate: exceptional
# Juego: Middle-earth: Shadow of Mordor | Rate: recommended
# Juego: The Witcher: Enhanced Edition Director's Cut | Rate: recommended
# Juego: BioShock 2 | Rate: recommended
# Juego: Half-Life 2: Episode One | Rate: exceptional

# %% [markdown]
# ### 4.3 Reviews de Rawg
#
# En el siguiente codigo podemos ver una gran diferencia entre ambas apis las cuales fue la de extracion de información ya que la api de Rawg a comparación de metacritic si cuenta con comentarios(reviews) sobre el juego y que tan bueno o malo es.
#
# en el siguiente codigo realizamos una función que solicitará el nombre del juego que deseas buscar y mostrará las reviews relacionadas con ese juego.

# %%
import requests

def extract_game_reviews():
    # Solicitar el nombre del juego al usuario
    game_name = input("Ingresa el nombre del juego: ")

    # URL de la API de RAWG para buscar el juego
    url = "https://api.rawg.io/api/games"

    # Parámetros de la solicitud
    params = {
        "key": "6a993b331c264a5995c5b548aa104274",  #api key
        "search": game_name,
        "page_size": 10,  # Número máximo de resultados
    }

    # Realizar la solicitud HTTP a la API para buscar el juego
    response = requests.get(url, params=params)

    # Comprobar el código de respuesta
    if response.status_code == 200:
        # Obtener la información de los juegos en formato JSON
        game_data = response.json()

        # Verificar si se encontraron juegos
        if game_data["count"] > 0:
            # Obtener el primer juego de los resultados
            game = game_data["results"][0]

            # Obtener el ID del juego
            game_id = game["id"]

            # URL de la API de RAWG para obtener las reviews del juego
            reviews_url = f"https://api.rawg.io/api/games/{game_id}/reviews"

            # Realizar la solicitud HTTP a la API para obtener las reviews del juego
            reviews_response = requests.get(reviews_url, params=params)

            # Comprobar el código de respuesta
            if reviews_response.status_code == 200:
                # Obtener la información de las reviews en formato JSON
                reviews_data = reviews_response.json()

                # Verificar si se encontraron reviews
                if reviews_data["count"] > 0:
                    # Iterar sobre las reviews y mostrarlas
                    print(f"Reviews del juego '{game_name}':")
                    for review in reviews_data["results"]:
                        review_text = review["text"]
                        print(f"- {review_text}")
                else:
                    print(f"No se encontraron reviews para el juego '{game_name}'.")
            else:
                print("Error al obtener las reviews del juego:", reviews_response.status_code)
        else:
            print(f"No se encontró el juego '{game_name}'.")
    else:
        print("Error al buscar el juego:", response.status_code)

# Ejemplo de uso: Extraer las reviews del juego deseado
extract_game_reviews()
# Out:
# Ingresa el nombre del juego: grand  theft auto v
# Reviews del juego 'grand  theft auto v':
# - Gta Online: What was a REALISTISCHES Game at first ... Where you accompany your Character on his Way as he completes missions and earns money to buy a nice Apartment has recently evolved into a Game about the ABSOLUTEN MEGALOMANIA.
# For example, at that Time the Adder (bugatti veyron) was the most popular Car in the Game and the most expensive and if you saw someone who drove him you knew that the one had ordaically "Cash in the Täsch" yet this changed unfortunately and cars became more expensive and Real estate ever crazier When you Join a Server these days, you'll find pretty much the following: You're standing in a place ... Where you might look at the mobile phone first and you want to transfer the Money you have, you hear it popping ... What happened? Another player drives you over without reason and shoots you without being able to get up.
# Since the update, it is also extremely common that one is killed by one of the new FLIEGENDEN Motorcycles or simply taken away by an Orbital satellite during a Mission. So around 500,000$ ... But this is for most Players no problem about 95% of Players have not earned their Money honestly.
# They have been given the Money by Modders or have multiplied It using Explode methods it is really sad that such an unrealistic and unfortunately broken Game has become full of Modders and Idiots.
# As for Rockstar's anticheat measures, these have failed across the Board, you see more People with a player level in The multi-digit dog range than ever before and Players who want to work out the Money honestly are doomed to be in Solo Sessions To grin missions to keep up with the others.
# - Now I also have to give up my Mustard to GTA V.
# SinglePlayer: The Game is typically GTA like simply horny and makes you feel Like it. Carts steal and mop up, trade on the Stock market (which gets a bit rogue with Time) and the Heists you can often pull through in several different Ways. Add to that the Special Abilities of each Character and the typical Open-World Feeling.
# In short: Must Whim and is a clear Buy recommendation Multiplayer For those who don't have it yet: Honestly, I have no Idea what Rockstar thought, but I think it was purely about coal. As a Beginner, you have hardly any Opportunities to afford even a little, especially if you play alone and no umpteen Friends to pull you along. Will be boring in the Long run.
# Worst Of all, though, are all the Kiddies that (almost all) had SxX with my Mum and howl unFlemish, and especially all the Cheaters. You are shot by a wandering PIXEL. Gaaaanz Big Cinema! As a Beginner, you are a Free Wlid for all The Idiots who go hunting With Tanks, Planes and heavy Weapons. Or you suddenly get Millions from an Unknown-and then get kicked by the oh so infallible Anti-cheat system and, if necessary, blocked it, as you got illegal InGame money. Suuper! Motivation high 10 so to speak:-/
# All the Updates are only available to buy even more Cash Cards, because as a normal mortal you can't buy the whole stuff anyway.
# In Summary, you have to say: If you want to play the game as a Single-player, you should strike when it is in the Sale, for example (like me). If YOU want to play MP, choose another Game, there are really better ones than the whole Pay-to-Win Remembrance here.
# And how to rate now? Difficult. SinglePlayer I highly recommend, but since only updates come out for the MP there are a fummy Down.
# Sorry, Rock Star, but you guys are too Money hungry for me.
# - A fun story with 3 memorable characters, a fun world to mess around in and apparently the multiplayer is based
# -  good
# - I only recommend half of this game. If you're interested in primarily the online, do not get your hopes up. It is extremely grindy and monetized like a free to play game. Most missions are bland and largely not worth doing from both a reward and fun perspective. Lobbies are also plagued with griefers and hackers.<br/><br/>Now onto the good half, story mode. Story mode offers a fun narrative with decent set pieces. The structure of the game does feel dated though. I know the game is called Grand theft Auto but there is so much brain dead driving back and forth, only being made somewhat bearable when dialogue is happening. Almost every mission, you need to drive to, then watch a cutscene, then drive somewhere else to do some shooting (or some other set piece); rinse and repeat. However, when you are not doing an excessive amount of driving, the missions are pretty enjoyable. Side missions though are a mixed bag. Some are good and others you're driving a slow tow truck to cover someone's job. Despite, all my gripes I still had a very good time with this game and I'd like to attribute this to the larger than life characters, heists, and set pieces.
# - Kind of a modern classic. Whether playing the entire story is worth it, its undoubtedly influential and a pinnacle of open world destruction fun.
# - I hate to give this game an exceptional, since it has changed rockstar from a video game company to a gtaonline company, but like damn.  This game is so good, both the single player and the online get an exceptional from me.
# - If you play the stroy you're going to enjoy it so much. The plot is very interesting and it maintains you hooked to the game. The secondary missions are enjoyable and they give you some more lore to the title. The online is not the best part at all but you can try it with some friends to be a little bit more fun. It gave me 44 hours of action and fun.
# - A must-play game for everyone. GTA 5 is so dynamic that will always feel yourself driving and chilling on roads.
# - The latest Grand Theft Auto game continues to have it's name driven further and further into the mud by it's online counterpart's predatory practices but the singleplayer remains as unapologetic and purely fun as it ever was. The game is an explosive heist movie that encourages destruction but knows when to tone down the wackiness and insert some real character moments. You can say what you want but the fact that I know Los Santos's downtown district and Bay Area better than I know my own city's streets despite living here my whole life is testament to its greatness.

# %%
Guardamos las reviews en un csv para una mejor manipulacion

# %%
import requests
import csv

def extract_game_reviews_to_csv():
    # Solicitar el nombre del juego al usuario
    game_name = input("Ingresa el nombre del juego: ")

    # URL de la API de RAWG para buscar el juego
    url = "https://api.rawg.io/api/games"

    # Parámetros de la solicitud
    params = {
        "key": "6a993b331c264a5995c5b548aa104274",  #  se necesita una API key para esta API específica
        "search": game_name,
        "page_size": 10,  # Número máximo de resultados
    }

    # Realizar la solicitud HTTP a la API para buscar el juego
    response = requests.get(url, params=params)

    # Comprobar el código de respuesta
    if response.status_code == 200:
        # Obtener la información de los juegos en formato JSON
        game_data = response.json()

        # Verificar si se encontraron juegos
        if game_data["count"] > 0:
            # Obtener el primer juego de los resultados
            game = game_data["results"][0]

            # Obtener el ID del juego
            game_id = game["id"]

            # URL de la API de RAWG para obtener las reviews del juego
            reviews_url = f"https://api.rawg.io/api/games/{game_id}/reviews"

            # Realizar la solicitud HTTP a la API para obtener las reviews del juego
            reviews_response = requests.get(reviews_url, params=params)

            # Comprobar el código de respuesta
            if reviews_response.status_code == 200:
                # Obtener la información de las reviews en formato JSON
                reviews_data = reviews_response.json()

                # Verificar si se encontraron reviews
                if reviews_data["count"] > 0:
                    # Crear un archivo CSV para almacenar las reviews
                    csv_filename = f"{game_name}_reviews.csv"
                    with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
                        writer = csv.writer(file)
                        writer.writerow(["Review"])

                        # Escribir las reviews en el archivo CSV
                        for review in reviews_data["results"]:
                            review_text = review["text"]
                            writer.writerow([review_text])

                    print(f"Las reviews del juego '{game_name}' se han guardado en '{csv_filename}'.")
                else:
                    print(f"No se encontraron reviews para el juego '{game_name}'.")
            else:
                print("Error al obtener las reviews del juego:", reviews_response.status_code)
        else:
            print(f"No se encontró el juego '{game_name}'.")
    else:
        print("Error al buscar el juego:", response.status_code)

# Ejemplo de uso: Extraer las reviews del juego deseado y guardarlas en un archivo CSV
extract_game_reviews_to_csv()
# Out:
# Ingresa el nombre del juego: grand theft auto v
# Las reviews del juego 'grand theft auto v' se han guardado en 'grand theft auto v_reviews.csv'.

# %% [markdown]
# ## 5. Integración de ambas apis
# Finalmente, podemos combinar el web scraping de Metacritic y RAWG para comparar los metascores de un juego específico.

# %%
import requests

def format_metacritic_game_name(game_name):
    # Reemplazar los espacios con guiones
    formatted_name = game_name.replace(" ", "-")

    return formatted_name

def compare_metascores(game_name):
    # Formatear el nombre del juego para Metacritic
    formatted_game_name = format_metacritic_game_name(game_name)

    # API de Rawg
    rawg_url = "https://api.rawg.io/api/games"
    rawg_params = {
        "key": "6a993b331c264a5995c5b548aa104274",
        "search": game_name,
        "page_size": 1
    }
    rawg_response = requests.get(rawg_url, params=rawg_params)
    rawg_data = rawg_response.json()

    if rawg_response.status_code == 200 and rawg_data["count"] > 0:
        rawg_metascore = rawg_data["results"][0]["metacritic"]

        print(f"Metascore de {game_name} en RAWG: {rawg_metascore}")
    else:
        print(f"No se encontró el juego '{game_name}' en RAWG.")

    # API de Metacritic
    metacritic_url = f"https://metacriticapi.p.rapidapi.com/games/{formatted_game_name}"
    headers = {
        "X-RapidAPI-Key": "9cec517409msh53db5f49ceb8bbdp194360jsn39f741c79e7a",
        "X-RapidAPI-Host": "metacriticapi.p.rapidapi.com"
    }
    metacritic_response = requests.get(metacritic_url, headers=headers)
    metacritic_data = metacritic_response.json()

    if metacritic_response.status_code == 200:
        metacritic_metascore = metacritic_data["metaScore"]

        print(f"Metascore de {game_name} en Metacritic: {metacritic_metascore}")
    else:
        print(f"No se encontró el juego '{game_name}' en Metacritic.")

    # Comparación de metascores
    if rawg_response.status_code == 200 and metacritic_response.status_code == 200:
        if rawg_metascore > metacritic_metascore:
            print("El metascore de RAWG es mayor que el de Metacritic.")
        elif rawg_metascore < metacritic_metascore:
            print("El metascore de Metacritic es mayor que el de RAWG.")
        else:
            print("El metascore de RAWG y Metacritic es el mismo.")

# Ejemplo de uso
compare_metascores("elden ring")
# Out:
# Metascore de elden ring en RAWG: 95
# Metascore de elden ring en Metacritic: 94
# El metascore de RAWG es mayor que el de Metacritic.

# %% [markdown]
# ## Integración de ambas Apis
# Solicitamos al usuario que ingrese el nombre del juego. Luego, utilizamos la función extract_game_info() para obtener información básica del juego desde RAWG, como el nombre, las plataformas y la fecha de lanzamiento. Después, utilizamos la función extract_metacritic_info() para obtener el metascore del juego desde Metacritic.
#
# De la api de rawg se obtiene: informacion del juego y reviews
# De la api de metacritic se obtiene: metascore y userscore

# %%
import requests

# Función para obtener información básica del juego desde RAWG
def extract_game_info(game_name):
    rawg_url = "https://api.rawg.io/api/games"
    rawg_params = {
        "key": "6a993b331c264a5995c5b548aa104274",
        "search": game_name,
        "page_size": 1
    }
    rawg_response = requests.get(rawg_url, params=rawg_params)
    rawg_data = rawg_response.json()

    if rawg_response.status_code == 200 and rawg_data["count"] > 0:
        game_info = rawg_data["results"][0]
        name = game_info["name"]
        platforms = game_info["platforms"]
        released = game_info["released"]
        
        print(f"Nombre del juego: {name}")
        print(f"Plataformas: {platforms}")
        print(f"Lanzamiento: {released}")
    else:
        print(f"No se encontró el juego '{game_name}' en RAWG.")

# Función para obtener el metascore y el userscore de Metacritic
def extract_metacritic_info(game_name):
    # Convertir el nombre del juego a formato de URL con guiones
    game_id = game_name.replace(" ", "-").lower()

    metacritic_url = f"https://metacriticapi.p.rapidapi.com/games/{game_id}"
    headers = {
        "X-RapidAPI-Key": "9cec517409msh53db5f49ceb8bbdp194360jsn39f741c79e7a",
        "X-RapidAPI-Host": "metacriticapi.p.rapidapi.com"
    }
    metacritic_response = requests.get(metacritic_url, headers=headers)
    metacritic_data = metacritic_response.json()

    if metacritic_response.status_code == 200:
        metascore = metacritic_data["metaScore"]
        userscore = metacritic_data["userScore"]
        print(f"Metascore en Metacritic: {metascore}")
        print(f"User Score en Metacritic: {userscore}")
    else:
        print(f"No se encontró el juego '{game_name}' en Metacritic.")

# Ejemplo de uso:
game_name = input("Ingresa el nombre del juego: ")

# Obtener información básica del juego desde RAWG
extract_game_info(game_name)

# Obtener el metascore y userscore del juego desde Metacritic
extract_metacritic_info(game_name)
# Out:
# Ingresa el nombre del juego: grand theft auto v
# Nombre del juego: Grand Theft Auto V
# Plataformas: [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}, {'platform': {'id': 187, 'name': 'PlayStation 5', 'slug': 'playstation5'}}, {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one'}}, {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4'}}, {'platform': {'id': 186, 'name': 'Xbox Series S/X', 'slug': 'xbox-series-x'}}, {'platform': {'id': 14, 'name': 'Xbox 360', 'slug': 'xbox360'}}, {'platform': {'id': 16, 'name': 'PlayStation 3', 'slug': 'playstation3'}}]
# Lanzamiento: 2013-09-17
# Metascore en Metacritic: 96
# User Score en Metacritic: 79

# %% [markdown]
# Ademas las apis se complementan bien ya que podemos permitimos al usuario ingresar el juego que deseé
# y La función realiza solicitudes a las API de Metacritic y RAWG para obtener información del juego.
#
# Para Metacritic, se realiza una solicitud utilizando el nombre del juego como parámetro de búsqueda y se extrae información como el título, el género y la descripción del juego.
#
# Para RAWG, se realiza una solicitud utilizando el nombre del juego como parámetro de búsqueda y se extrae información como la calificación (rating) del juego.

# %%
import requests

def extract_game_info(game_name):
    # Obtener información del juego desde Metacritic
    metacritic_url = f"https://metacriticapi.p.rapidapi.com/games"
    metacritic_params = {
        "title": game_name
    }
    metacritic_headers = {
        "X-RapidAPI-Key": "9cec517409msh53db5f49ceb8bbdp194360jsn39f741c79e7a",
        "X-RapidAPI-Host": "metacriticapi.p.rapidapi.com"
    }
    metacritic_response = requests.get(metacritic_url, params=metacritic_params, headers=metacritic_headers)
    metacritic_data = metacritic_response.json()

    if metacritic_response.status_code == 200 and len(metacritic_data) > 0:
        # Obtener información básica del primer juego de los resultados
        game_info = metacritic_data[0]
        title = game_info["title"]
        genre = game_info["genre"]
        description = game_info["description"]

        print("Información del juego desde Metacritic:")
        print(f"Título: {title}")
        print(f"Género: {genre}")
        print(f"Descripción: {description}")
    else:
        print(f"No se encontró el juego '{game_name}' en Metacritic.")

    # Obtener el rating del juego desde RAWG
    rawg_url = "https://api.rawg.io/api/games"
    rawg_params = {
        "key": "6a993b331c264a5995c5b548aa104274",
        "search": game_name,
        "page_size": 1
    }
    rawg_response = requests.get(rawg_url, params=rawg_params)
    rawg_data = rawg_response.json()

    if rawg_response.status_code == 200 and rawg_data["count"] > 0:
        game_info = rawg_data["results"][0]
        rating = game_info["rating"]

        print("Información del juego desde RAWG:")
        print(f"Rating: {rating}")
    else:
        print(f"No se encontró el juego '{game_name}' en RAWG.")

# Ejemplo de uso:
game_name = input("Ingresa el nombre del juego: ")
extract_game_info(game_name)
# Out:
# Ingresa el nombre del juego: grand theft auto v
# Información del juego desde Metacritic:
# Título: Crime O'Clock
# Género: action
# Descripción: ALERT! ALERT! TIMESHIFT CONTINUUM AT RISK!Prevent crimes before they happen! It's Crime O'Clock!Crime O'Clock is an investigation and time exploration game with a deep storyline. Investigate cases through time and evolving maps by unveiling a multi-eras linked story. Will you be observant enough to solve the mysteries? Crime waits for no man!As a time detective, your job is to solve crimes through time that should never have happened! Each map has multiple time markers to visit and use to resolve different cases of hacking, murder, theft, and much more.
# Información del juego desde RAWG:
# Rating: 4.47

# %%
pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: textblob in c:\users\user\appdata\roaming\python\python310\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in d:\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: joblib in d:\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in d:\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: click in d:\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import matplotlib.pyplot as plt

def extract_all_game_rates():
    # URL de la API de RAWG para obtener los juegos
    url = "https://api.rawg.io/api/games"

    # Parámetros de la solicitud
    params = {
        "key": "6a993b331c264a5995c5b548aa104274",  # No se necesita una API key para esta API específica
        "page_size": 10,  # Limitar la cantidad de juegos a 10
    }

    # Realizar la solicitud HTTP a la API para obtener los juegos
    response = requests.get(url, params=params)

    # Comprobar el código de respuesta
    if response.status_code == 200:
        # Obtener la información de los juegos en formato JSON
        game_data = response.json()

        # Verificar si se encontraron juegos
        if game_data["count"] > 0:
            # Ordenar los juegos por calificación (de mayor a menor)
            sorted_games = sorted(game_data["results"], key=lambda x: x["rating_top"], reverse=True)

            # Crear listas para almacenar los nombres de los juegos y las calificaciones
            game_names = []
            ratings = []

            # Iterar sobre los primeros 10 juegos y obtener los nombres y las calificaciones
            for game in sorted_games[:10]:
                game_name = game["name"]
                game_rating = game["rating_top"]

                game_names.append(game_name)
                ratings.append(game_rating)

            # Crear el gráfico de líneas
            plt.plot(game_names, ratings)
            plt.xlabel("Juegos")
            plt.ylabel("Calificación")
            plt.title("Calificación de los 10 mejores juegos")
            plt.xticks(rotation=90)
            plt.show()
        else:
            print("No se encontraron juegos.")
    else:
        print("Error al obtener los juegos:", response.status_code)

# Ejemplo de uso: Extraer y graficar la calificación de los 10 mejores juegos
extract_all_game_rates()
